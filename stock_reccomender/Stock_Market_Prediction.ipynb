# %% [markdown]
# # Predict stock price
# Playing around with stock price data and predictions
# Ideally, also quantum computing but we'll save that for later
# Steve Smith, Feb 2025

# %%
import numpy as np
import pandas as pd
import requests
import json
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error
# Out:
# /Users/stevensmith/Projects/python_virtual_envs/githubmatcher/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from config import API_KEY
# Out:
# 'your-secret-key'

# %%
# from qiskit import QuantumCircuit
# from qiskit.circuit.library import PauliFeatureMap
# from qiskit.algorithms.optimizers import ADAM
# from qiskit.circuit import Parameter
# from qiskit.primitives import Sampler

# %%
api_url = "https://financialmodelingprep.com/api/v3/historical-price-full/AAPL?apikey="+API_KEY
# Make a GET request to the API
response = requests.get(api_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the response JSON
    data = response.json()
else:
    print(f"Error: Unable to fetch data. Status code: {response.status_code}")

data
# Out:
# {'symbol': 'AAPL',
#  'historical': [{'date': '2025-02-10',
#    'open': 229.57,
#    'high': 230.59,
#    'low': 227.2,
#    'close': 227.65,
#    'adjClose': 227.65,
#    'volume': 31646695,
#    'unadjustedVolume': 31646695,
#    'change': -1.92,
#    'changePercent': -0.83635,
#    'vwap': 228.7525,
#    'label': 'February 10, 25',
#    'changeOverTime': -0.0083635},
#   {'date': '2025-02-07',
#    'open': 232.6,
#    'high': 234,
#    'low': 227.26,
#    'close': 227.63,
#    'adjClose': 227.38,
#    'volume': 39707224,
#    'unadjustedVolume': 39707224,
#    'change': -4.97,
#    'changePercent': -2.14,
#    'vwap': 230.3725,
#    'label': 'February 07, 25',
#    'changeOverTime': -0.0214},
#   {'date': '2025-02-06',
#    'open': 231.29,
#    'high': 233.8,
#    'low': 230.43,
#    'close': 233.22,
#    'adjClose': 232.96,
#    'volume': 29925349,
#    'unadjustedVolume': 29925349,
#    'change': 1.94,
#    'changePercent': 0.83445,
#    'vwap': 232.185,
#    'label': 'February 06, 25',
#    'changeOverTime': 0.0083445},
#   {'date': '2025-02-05',
#    'open': 228.53,
#    'high': 232.67,
#    'low': 228.27,
#    'close': 232.47,
#    'adjClose': 232.21,
#    'volume': 39664989,
#    'unadjustedVolume': 39664989,
#    'change': 3.94,
#    'changePercent': 1.72,
#    'vwap': 230.485,
#    'label': 'February 05, 25',
#    'changeOverTime': 0.0172},
#   {'date': '2025-02-04',
#    'open': 227.25,
#    'high': 233.13,
#    'low': 226.65,
#    'close': 232.8,
#    'adjClose': 232.54,
#    'volume': 45067301,
#    'unadjustedVolume': 45067301,
#    'change': 5.55,
#    'changePercent': 2.44,
#    'vwap': 229.9575,
#    'label': 'February 04, 25',
#    'changeOverTime': 0.0244},
#   {'date': '2025-02-03',
#    'open': 229.99,
#    'high': 231.83,
#    'low': 225.7,
#    'close': 228.01,
#    'adjClose': 227.76,
#    'volume': 73063301,
#    'unadjustedVolume': 73063301,
#    'change': -1.98,
#    'changePercent': -0.86091,
#    'vwap': 228.8825,
#    'label': 'February 03, 25',
#    'changeOverTime': -0.0086091},
#   {'date': '2025-01-31',
#    'open': 247.19,
#    'high': 247.19,
#    'low': 233.44,
#    'close': 236,
#    'adjClose': 235.74,
#    'volume': 101075128,
#    'unadjustedVolume': 101075128,
#    'change': -11.19,
#    'changePercent': -4.53,
#    'vwap': 240.955,
#    'label': 'January 31, 25',
#    'changeOverTime': -0.0453},
#   {'date': '2025-01-30',
#    'open': 238.67,
#    'high': 240.79,
#    'low': 237.21,
#    'close': 237.59,
#    'adjClose': 237.33,
#    'volume': 55658300,
#    'unadjustedVolume': 55658300,
#    'change': -1.07,
#    'changePercent': -0.45251,
#    'vwap': 238.565,
#    'label': 'January 30, 25',
#    'changeOverTime': -0.0045251},
#   {'date': '2025-01-29',
#    'open': 234.12,
#    'high': 239.86,
#    'low': 234.01,
#    'close': 239.36,
#    'adjClose': 239.1,
#    'volume': 45486100,
#    'unadjustedVolume': 45486100,
#    'change': 5.24,
#    'changePercent': 2.24,
#    'vwap': 236.8375,
#    'label': 'January 29, 25',
#    'changeOverTime': 0.0224},
#   {'date': '2025-01-28',
#    'open': 230.85,
#    'high': 240.19,
#    'low': 230.81,
#    'close': 238.26,
#    'adjClose': 238,
#    'volume': 75707600,
#    'unadjustedVolume': 75707600,
#    'change': 7.41,
#    'changePercent': 3.21,
#    'vwap': 235.0275,
#    'label': 'January 28, 25',
#    'changeOverTime': 0.0321},
#   {'date': '2025-01-27',
#    'open': 224.02,
#    'high': 232.15,
#    'low': 223.98,
#    'close': 229.86,
#    'adjClose': 229.61,
#    'volume': 94863418,
#    'unadjustedVolume': 94863418,
#    'change': 5.84,
#    'changePercent': 2.61,
#    'vwap': 227.5025,
#    'label': 'January 27, 25',
#    'changeOverTime': 0.0261},
#   {'date': '2025-01-24',
#    'open': 224.78,
#    'high': 225.63,
#    'low': 221.41,
#    'close': 222.78,
#    'adjClose': 222.54,
#    'volume': 54697907,
#    'unadjustedVolume': 54697907,
#    'change': -2,
#    'changePercent': -0.88976,
#    'vwap': 223.65,
#    'label': 'January 24, 25',
#    'changeOverTime': -0.0088976},
#   {'date': '2025-01-23',
#    'open': 224.74,
#    'high': 227.03,
#    'low': 222.3,
#    'close': 223.66,
#    'adjClose': 223.41,
#    'volume': 60234800,
#    'unadjustedVolume': 60234800,
#    'change': -1.08,
#    'changePercent': -0.48056,
#    'vwap': 224.4325,
#    'label': 'January 23, 25',
#    'changeOverTime': -0.0048056},
#   {'date': '2025-01-22',
#    'open': 219.79,
#    'high': 224.12,
#    'low': 219.79,
#    'close': 223.83,
#    'adjClose': 223.58,
#    'volume': 64126500,
#    'unadjustedVolume': 64126500,
#    'change': 4.04,
#    'changePercent': 1.84,
#    'vwap': 221.8825,
#    'label': 'January 22, 25',
#    'changeOverTime': 0.0184},
#   {'date': '2025-01-21',
#    'open': 224,
#    'high': 224.42,
#    'low': 219.38,
#    'close': 222.64,
#    'adjClose': 222.4,
#    'volume': 98070429,
#    'unadjustedVolume': 98070429,
#    'change': -1.36,
#    'changePercent': -0.60714,
#    'vwap': 222.61,
#    'label': 'January 21, 25',
#    'changeOverTime': -0.0060714},
#   {'date': '2025-01-17',
#    'open': 232.12,
#    'high': 232.29,
#    'low': 228.48,
#    'close': 229.98,
#    'adjClose': 229.73,
#    'volume': 68488301,
#    'unadjustedVolume': 68488301,
#    'change': -2.14,
#    'changePercent': -0.92194,
#    'vwap': 230.7175,
#    'label': 'January 17, 25',
#    'changeOverTime': -0.0092194},
#   {'date': '2025-01-16',
#    'open': 237.35,
#    'high': 238.01,
#    'low': 228.03,
#    'close': 228.26,
#    'adjClose': 228.01,
#    'volume': 71759100,
#    'unadjustedVolume': 71759100,
#    'change': -9.09,
#    'changePercent': -3.83,
#    'vwap': 232.9125,
#    'label': 'January 16, 25',
#    'changeOverTime': -0.0383},
#   {'date': '2025-01-15',
#    'open': 234.64,
#    'high': 238.96,
#    'low': 234.43,
#    'close': 237.87,
#    'adjClose': 237.61,
#    'volume': 39832000,
#    'unadjustedVolume': 39832000,
#    'change': 3.24,
#    'changePercent': 1.38,
#    'vwap': 236.475,
#    'label': 'January 15, 25',
#    'changeOverTime': 0.0138},
#   {'date': '2025-01-14',
#    'open': 234.75,
#    'high': 236.12,
#    'low': 232.47,
#    'close': 233.28,
#    'adjClose': 233.02,
#    'volume': 39435300,
#    'unadjustedVolume': 39435300,
#    'change': -1.47,
#    'changePercent': -0.6262,
#    'vwap': 234.155,
#    'label': 'January 14, 25',
#    'changeOverTime': -0.006262},
#   {'date': '2025-01-13',
#    'open': 233.53,
#    'high': 234.67,
#    'low': 229.72,
#    'close': 234.4,
#    'adjClose': 234.14,
#    'volume': 49630725,
#    'unadjustedVolume': 49630725,
#    'change': 0.87,
#    'changePercent': 0.37254,
#    'vwap': 233.08,
#    'label': 'January 13, 25',
#    'changeOverTime': 0.0037254},
#   {'date': '2025-01-10',
#    'open': 240.01,
#    'high': 240.16,
#    'low': 233,
#    'close': 236.85,
#    'adjClose': 236.85,
#    'volume': 61710900,
#    'unadjustedVolume': 61710900,
#    'change': -3.16,
#    'changePercent': -1.32,
#    'vwap': 237.505,
#    'label': 'January 10, 25',
#    'changeOverTime': -0.0132},
#   {'date': '2025-01-08',
#    'open': 241.92,
#    'high': 243.71,
#    'low': 240.05,
#    'close': 242.7,
#    'adjClose': 242.7,
#    'volume': 37628940,
#    'unadjustedVolume': 37628940,
#    'change': 0.78,
#    'changePercent': 0.32242,
#    'vwap': 242.095,
#    'label': 'January 08, 25',
#    'changeOverTime': 0.0032242},
#   {'date': '2025-01-07',
#    'open': 242.98,
#    'high': 245.55,
#    'low': 241.35,
#    'close': 242.21,
#    'adjClose': 242.21,
#    'volume': 40856000,
#    'unadjustedVolume': 40856000,
#    'change': -0.77,
#    'changePercent': -0.3169,
#    'vwap': 243.0225,
#    'label': 'January 07, 25',
#    'changeOverTime': -0.003169},
#   {'date': '2025-01-06',
#    'open': 244.31,
#    'high': 247.33,
#    'low': 243.2,
#    'close': 245,
#    'adjClose': 245,
#    'volume': 45045600,
#    'unadjustedVolume': 45045600,
#    'change': 0.69,
#    'changePercent': 0.28243,
#    'vwap': 244.96,
#    'label': 'January 06, 25',
#    'changeOverTime': 0.0028243},
#   {'date': '2025-01-03',
#    'open': 243.36,
#    'high': 244.18,
#    'low': 241.89,
#    'close': 243.36,
#    'adjClose': 243.36,
#    'volume': 40244114,
#    'unadjustedVolume': 40244114,
#    'change': 0,
#    'changePercent': 0,
#    'vwap': 243.1975,
#    'label': 'January 03, 25',
#    'changeOverTime': 0},
#   {'date': '2025-01-02',
#    'open': 248.93,
#    'high': 249.1,
#    'low': 241.82,
#    'close': 243.85,
#    'adjClose': 243.85,
#    'volume': 55740731,
#    'unadjustedVolume': 55740731,
#    'change': -5.08,
#    'changePercent': -2.04,
#    'vwap': 245.925,
#    'label': 'January 02, 25',
#    'changeOverTime': -0.0204},
#   {'date': '2024-12-31',
#    'open': 252.44,
#    'high': 253.28,
#    'low': 249.43,
#    'close': 250.42,
#    'adjClose': 250.42,
#    'volume': 39480718,
#    'unadjustedVolume': 39480718,
#    'change': -2.02,
#    'changePercent': -0.80019,
#    'vwap': 251.3925,
#    'label': 'December 31, 24',
#    'changeOverTime': -0.0080019},
#   {'date': '2024-12-30',
#    'open': 252.23,
#    'high': 253.5,
#    'low': 250.75,
#    'close': 252.2,
#    'adjClose': 252.2,
#    'volume': 35557542,
#    'unadjustedVolume': 35557542,
#    'change': -0.03,
#    'changePercent': -0.01189391,
#    'vwap': 252.17,
#    'label': 'December 30, 24',
#    'changeOverTime': -0.0001189391},
#   {'date': '2024-12-27',
#    'open': 257.83,
#    'high': 258.7,
#    'low': 253.06,
#    'close': 255.59,
#    'adjClose': 255.59,
#    'volume': 42355321,
#    'unadjustedVolume': 42355321,
#    'change': -2.24,
#    'changePercent': -0.86879,
#    'vwap': 256.295,
#    'label': 'December 27, 24',
#    'changeOverTime': -0.0086879},
#   {'date': '2024-12-26',
#    'open': 258.19,
#    'high': 260.1,
#    'low': 257.63,
#    'close': 259.02,
#    'adjClose': 259.02,
#    'volume': 27263000,
#    'unadjustedVolume': 27263000,
#    'change': 0.83,
#    'changePercent': 0.32147,
#    'vwap': 258.735,
#    'label': 'December 26, 24',
#    'changeOverTime': 0.0032147},
#   {'date': '2024-12-24',
#    'open': 255.49,
#    'high': 258.21,
#    'low': 255.29,
#    'close': 258.2,
#    'adjClose': 258.2,
#    'volume': 23234705,
#    'unadjustedVolume': 23234705,
#    'change': 2.71,
#    'changePercent': 1.06,
#    'vwap': 256.7975,
#    'label': 'December 24, 24',
#    'changeOverTime': 0.0106},
#   {'date': '2024-12-23',
#    'open': 254.77,
#    'high': 255.65,
#    'low': 253.45,
#    'close': 255.27,
#    'adjClose': 255.27,
#    'volume': 40858800,
#    'unadjustedVolume': 40858800,
#    'change': 0.5,
#    'changePercent': 0.19626,
#    'vwap': 254.785,
#    'label': 'December 23, 24',
#    'changeOverTime': 0.0019626},
#   {'date': '2024-12-20',
#    'open': 248.04,
#    'high': 255,
#    'low': 245.69,
#    'close': 254.49,
#    'adjClose': 254.49,
#    'volume': 147495300,
#    'unadjustedVolume': 147495300,
#    'change': 6.45,
#    'changePercent': 2.6,
#    'vwap': 250.805,
#    'label': 'December 20, 24',
#    'changeOverTime': 0.026},
#   {'date': '2024-12-19',
#    'open': 247.5,
#    'high': 252,
#    'low': 247.09,
#    'close': 249.79,
#    'adjClose': 249.79,
#    'volume': 60882300,
#    'unadjustedVolume': 60882300,
#    'change': 2.29,
#    'changePercent': 0.92525,
#    'vwap': 249.095,
#    'label': 'December 19, 24',
#    'changeOverTime': 0.0092525},
#   {'date': '2024-12-18',
#    'open': 252.16,
#    'high': 254.28,
#    'low': 247.74,
#    'close': 248.05,
#    'adjClose': 248.05,
#    'volume': 56774101,
#    'unadjustedVolume': 56774101,
#    'change': -4.11,
#    'changePercent': -1.63,
#    'vwap': 250.5575,
#    'label': 'December 18, 24',
#    'changeOverTime': -0.0163},
#   {'date': '2024-12-17',
#    'open': 250.08,
#    'high': 253.83,
#    'low': 249.78,
#    'close': 253.48,
#    'adjClose': 253.48,
#    'volume': 51356400,
#    'unadjustedVolume': 51356400,
#    'change': 3.4,
#    'changePercent': 1.36,
#    'vwap': 251.7925,
#    'label': 'December 17, 24',
#    'changeOverTime': 0.0136},
#   {'date': '2024-12-16',
#    'open': 247.99,
#    'high': 251.38,
#    'low': 247.65,
#    'close': 251.04,
#    'adjClose': 251.04,
#    'volume': 51694800,
#    'unadjustedVolume': 51694800,
#    'change': 3.05,
#    'changePercent': 1.23,
#    'vwap': 249.515,
#    'label': 'December 16, 24',
#    'changeOverTime': 0.0123},
#   {'date': '2024-12-13',
#    'open': 247.82,
#    'high': 249.29,
#    'low': 246.24,
#    'close': 248.13,
#    'adjClose': 248.13,
#    'volume': 33155300,
#    'unadjustedVolume': 33155300,
#    'change': 0.315,
#    'changePercent': 0.12509,
#    'vwap': 247.87,
#    'label': 'December 13, 24',
#    'changeOverTime': 0.0012509},
#   {'date': '2024-12-12',
#    'open': 246.89,
#    'high': 248.74,
#    'low': 245.68,
#    'close': 247.96,
#    'adjClose': 247.96,
#    'volume': 32777532,
#    'unadjustedVolume': 32777532,
#    'change': 1.07,
#    'changePercent': 0.43339,
#    'vwap': 247.3175,
#    'label': 'December 12, 24',
#    'changeOverTime': 0.0043339},
#   {'date': '2024-12-11',
#    'open': 247.96,
#    'high': 250.8,
#    'low': 246.26,
#    'close': 246.49,
#    'adjClose': 246.49,
#    'volume': 45205814,
#    'unadjustedVolume': 45205814,
#    'change': -1.47,
#    'changePercent': -0.59284,
#    'vwap': 247.8775,
#    'label': 'December 11, 24',
#    'changeOverTime': -0.0059284},
#   {'date': '2024-12-10',
#    'open': 246.89,
#    'high': 248.21,
#    'low': 245.34,
#    'close': 247.77,
#    'adjClose': 247.77,
#    'volume': 36914806,
#    'unadjustedVolume': 36914806,
#    'change': 0.88,
#    'changePercent': 0.35643,
#    'vwap': 247.0525,
#    'label': 'December 10, 24',
#    'changeOverTime': 0.0035643},
#   {'date': '2024-12-09',
#    'open': 241.83,
#    'high': 247.24,
#    'low': 241.75,
#    'close': 246.75,
#    'adjClose': 246.75,
#    'volume': 44649232,
#    'unadjustedVolume': 44649232,
#    'change': 4.92,
#    'changePercent': 2.03,
#    'vwap': 244.3925,
#    'label': 'December 09, 24',
#    'changeOverTime': 0.0203},
#   {'date': '2024-12-06',
#    'open': 242.91,
#    'high': 244.63,
#    'low': 242.08,
#    'close': 242.84,
#    'adjClose': 242.84,
#    'volume': 36870619,
#    'unadjustedVolume': 36870619,
#    'change': -0.065,
#    'changePercent': -0.02881726,
#    'vwap': 243.115,
#    'label': 'December 06, 24',
#    'changeOverTime': -0.0002881726},
#   {'date': '2024-12-05',
#    'open': 243.99,
#    'high': 244.54,
#    'low': 242.13,
#    'close': 243.04,
#    'adjClose': 243.04,
#    'volume': 40033900,
#    'unadjustedVolume': 40033900,
#    'change': -0.95,
#    'changePercent': -0.38936,
#    'vwap': 243.425,
#    'label': 'December 05, 24',
#    'changeOverTime': -0.0038936},
#   {'date': '2024-12-04',
#    'open': 242.87,
#    'high': 244.11,
#    'low': 241.25,
#    'close': 243.01,
#    'adjClose': 243.01,
#    'volume': 44383935,
#    'unadjustedVolume': 44383935,
#    'change': 0.14,
#    'changePercent': 0.05764401,
#    'vwap': 242.81,
#    'label': 'December 04, 24',
#    'changeOverTime': 0.0005764401},
#   {'date': '2024-12-03',
#    'open': 239.81,
#    'high': 242.76,
#    'low': 238.9,
#    'close': 242.65,
#    'adjClose': 242.65,
#    'volume': 38861017,
#    'unadjustedVolume': 38861017,
#    'change': 2.84,
#    'changePercent': 1.18,
#    'vwap': 241.03,
#    'label': 'December 03, 24',
#    'changeOverTime': 0.0118},
#   {'date': '2024-12-02',
#    'open': 237.27,
#    'high': 240.79,
#    'low': 237.16,
#    'close': 239.59,
#    'adjClose': 239.59,
#    'volume': 48137103,
#    'unadjustedVolume': 48137103,
#    'change': 2.32,
#    'changePercent': 0.97779,
#    'vwap': 238.7025,
#    'label': 'December 02, 24',
#    'changeOverTime': 0.0097779},
#   {'date': '2024-11-29',
#    'open': 234.81,
#    'high': 237.81,
#    'low': 233.97,
#    'close': 237.33,
#    'adjClose': 237.33,
#    'volume': 28481400,
#    'unadjustedVolume': 28481400,
#    'change': 2.53,
#    'changePercent': 1.07,
#    'vwap': 235.98,
#    'label': 'November 29, 24',
#    'changeOverTime': 0.0107},
#   {'date': '2024-11-27',
#    'open': 234.47,
#    'high': 235.69,
#    'low': 233.81,
#    'close': 234.93,
#    'adjClose': 234.93,
#    'volume': 33498439,
#    'unadjustedVolume': 33498439,
#    'change': 0.465,
#    'changePercent': 0.19619,
#    'vwap': 234.725,
#    'label': 'November 27, 24',
#    'changeOverTime': 0.0019619},
#   {'date': '2024-11-26',
#    'open': 233.33,
#    'high': 235.57,
#    'low': 233.33,
#    'close': 235.06,
#    'adjClose': 235.06,
#    'volume': 45986200,
#    'unadjustedVolume': 45986200,
#    'change': 1.73,
#    'changePercent': 0.74144,
#    'vwap': 234.3225,
#    'label': 'November 26, 24',
#    'changeOverTime': 0.0074144},
#   {'date': '2024-11-25',
#    'open': 231.46,
#    'high': 233.25,
#    'low': 229.74,
#    'close': 232.87,
#    'adjClose': 232.87,
#    'volume': 90152832,
#    'unadjustedVolume': 90152832,
#    'change': 1.41,
#    'changePercent': 0.60918,
#    'vwap': 231.83,
#    'label': 'November 25, 24',
#    'changeOverTime': 0.0060918},
#   {'date': '2024-11-22',
#    'open': 228.06,
#    'high': 230.72,
#    'low': 228.06,
#    'close': 229.87,
#    'adjClose': 229.87,
#    'volume': 38168300,
#    'unadjustedVolume': 38168300,
#    'change': 1.81,
#    'changePercent': 0.79365,
#    'vwap': 229.1775,
#    'label': 'November 22, 24',
#    'changeOverTime': 0.0079365},
#   {'date': '2024-11-21',
#    'open': 228.88,
#    'high': 230.16,
#    'low': 225.71,
#    'close': 228.52,
#    'adjClose': 228.52,
#    'volume': 42108327,
#    'unadjustedVolume': 42108327,
#    'change': -0.36,
#    'changePercent': -0.15729,
#    'vwap': 228.3175,
#    'label': 'November 21, 24',
#    'changeOverTime': -0.0015729},
#   {'date': '2024-11-20',
#    'open': 228.06,
#    'high': 229.93,
#    'low': 225.89,
#    'close': 229,
#    'adjClose': 229,
#    'volume': 35169600,
#    'unadjustedVolume': 35169600,
#    'change': 0.94,
#    'changePercent': 0.41217,
#    'vwap': 228.22,
#    'label': 'November 20, 24',
#    'changeOverTime': 0.0041217},
#   {'date': '2024-11-19',
#    'open': 226.98,
#    'high': 230.16,
#    'low': 226.66,
#    'close': 228.28,
#    'adjClose': 228.28,
#    'volume': 36211800,
#    'unadjustedVolume': 36211800,
#    'change': 1.3,
#    'changePercent': 0.57274,
#    'vwap': 228.02,
#    'label': 'November 19, 24',
#    'changeOverTime': 0.0057274},
#   {'date': '2024-11-18',
#    'open': 225.25,
#    'high': 229.74,
#    'low': 225.17,
#    'close': 228.02,
#    'adjClose': 228.02,
#    'volume': 44686020,
#    'unadjustedVolume': 44686020,
#    'change': 2.77,
#    'changePercent': 1.23,
#    'vwap': 227.045,
#    'label': 'November 18, 24',
#    'changeOverTime': 0.0123},
#   {'date': '2024-11-15',
#    'open': 226.4,
#    'high': 226.92,
#    'low': 224.27,
#    'close': 225,
#    'adjClose': 225,
#    'volume': 47923700,
#    'unadjustedVolume': 47923700,
#    'change': -1.4,
#    'changePercent': -0.61837,
#    'vwap': 225.6475,
#    'label': 'November 15, 24',
#    'changeOverTime': -0.0061837},
#   {'date': '2024-11-14',
#    'open': 225.02,
#    'high': 228.87,
#    'low': 225,
#    'close': 228.22,
#    'adjClose': 228.22,
#    'volume': 44923941,
#    'unadjustedVolume': 44923941,
#    'change': 3.2,
#    'changePercent': 1.42,
#    'vwap': 226.7775,
#    'label': 'November 14, 24',
#    'changeOverTime': 0.0142},
#   {'date': '2024-11-13',
#    'open': 224.01,
#    'high': 226.65,
#    'low': 222.76,
#    'close': 225.12,
#    'adjClose': 225.12,
#    'volume': 48566217,
#    'unadjustedVolume': 48566217,
#    'change': 1.11,
#    'changePercent': 0.49551,
#    'vwap': 224.635,
#    'label': 'November 13, 24',
#    'changeOverTime': 0.0049551},
#   {'date': '2024-11-12',
#    'open': 224.55,
#    'high': 225.59,
#    'low': 223.36,
#    'close': 224.23,
#    'adjClose': 224.23,
#    'volume': 40398300,
#    'unadjustedVolume': 40398300,
#    'change': -0.32,
#    'changePercent': -0.14251,
#    'vwap': 224.4325,
#    'label': 'November 12, 24',
#    'changeOverTime': -0.0014251},
#   {'date': '2024-11-11',
#    'open': 225,
#    'high': 225.7,
#    'low': 221.5,
#    'close': 224.23,
#    'adjClose': 224.23,
#    'volume': 42005602,
#    'unadjustedVolume': 42005602,
#    'change': -0.77,
#    'changePercent': -0.34222,
#    'vwap': 224.1075,
#    'label': 'November 11, 24',
#    'changeOverTime': -0.0034222},
#   {'date': '2024-11-08',
#    'open': 227.17,
#    'high': 228.66,
#    'low': 226.41,
#    'close': 226.96,
#    'adjClose': 226.96,
#    'volume': 38328824,
#    'unadjustedVolume': 38328824,
#    'change': -0.21,
#    'changePercent': -0.09244178,
#    'vwap': 227.3,
#    'label': 'November 08, 24',
#    'changeOverTime': -0.0009244178},
#   {'date': '2024-11-07',
#    'open': 224.63,
#    'high': 227.88,
#    'low': 224.57,
#    'close': 227.48,
#    'adjClose': 227.23,
#    'volume': 42137700,
#    'unadjustedVolume': 42137700,
#    'change': 2.85,
#    'changePercent': 1.27,
#    'vwap': 226.14,
#    'label': 'November 07, 24',
#    'changeOverTime': 0.0127},
#   {'date': '2024-11-06',
#    'open': 222.61,
#    'high': 226.07,
#    'low': 221.19,
#    'close': 222.72,
#    'adjClose': 222.48,
#    'volume': 54561121,
#    'unadjustedVolume': 54561121,
#    'change': 0.11,
#    'changePercent': 0.04941377,
#    'vwap': 223.1475,
#    'label': 'November 06, 24',
#    'changeOverTime': 0.0004941377},
#   {'date': '2024-11-05',
#    'open': 221.8,
#    'high': 223.95,
#    'low': 221.14,
#    'close': 223.45,
#    'adjClose': 223.2,
#    'volume': 28111338,
#    'unadjustedVolume': 28111338,
#    'change': 1.66,
#    'changePercent': 0.74391,
#    'vwap': 222.585,
#    'label': 'November 05, 24',
#    'changeOverTime': 0.0074391},
#   {'date': '2024-11-04',
#    'open': 220.99,
#    'high': 222.79,
#    'low': 219.71,
#    'close': 222.01,
#    'adjClose': 221.77,
#    'volume': 44944500,
#    'unadjustedVolume': 44944500,
#    'change': 1.02,
#    'changePercent': 0.46156,
#    'vwap': 221.375,
#    'label': 'November 04, 24',
#    'changeOverTime': 0.0046156},
#   {'date': '2024-11-01',
#    'open': 220.97,
#    'high': 225.35,
#    'low': 220.27,
#    'close': 222.91,
#    'adjClose': 222.67,
#    'volume': 65276741,
#    'unadjustedVolume': 65276741,
#    'change': 1.94,
#    'changePercent': 0.87795,
#    'vwap': 222.375,
#    'label': 'November 01, 24',
#    'changeOverTime': 0.0087795},
#   {'date': '2024-10-31',
#    'open': 229.34,
#    'high': 229.83,
#    'low': 225.37,
#    'close': 225.91,
#    'adjClose': 225.66,
#    'volume': 64370100,
#    'unadjustedVolume': 64370100,
#    'change': -3.43,
#    'changePercent': -1.5,
#    'vwap': 227.6125,
#    'label': 'October 31, 24',
#    'changeOverTime': -0.015},
#   {'date': '2024-10-30',
#    'open': 232.61,
#    'high': 233.47,
#    'low': 229.55,
#    'close': 230.1,
#    'adjClose': 229.85,
#    'volume': 47070907,
#    'unadjustedVolume': 47070907,
#    'change': -2.51,
#    'changePercent': -1.08,
#    'vwap': 231.4325,
#    'label': 'October 30, 24',
#    'changeOverTime': -0.0108},
#   {'date': '2024-10-29',
#    'open': 233.1,
#    'high': 234.33,
#    'low': 232.32,
#    'close': 233.67,
#    'adjClose': 233.41,
#    'volume': 35417247,
#    'unadjustedVolume': 35417247,
#    'change': 0.57,
#    'changePercent': 0.24453,
#    'vwap': 233.355,
#    'label': 'October 29, 24',
#    'changeOverTime': 0.0024453},
#   {'date': '2024-10-28',
#    'open': 233.32,
#    'high': 234.73,
#    'low': 232.55,
#    'close': 233.4,
#    'adjClose': 233.14,
#    'volume': 36087134,
#    'unadjustedVolume': 36087134,
#    'change': 0.08,
#    'changePercent': 0.03428767,
#    'vwap': 233.5,
#    'label': 'October 28, 24',
#    'changeOverTime': 0.0003428767},
#   {'date': '2024-10-25',
#    'open': 229.74,
#    'high': 233.22,
#    'low': 229.57,
#    'close': 231.41,
#    'adjClose': 231.16,
#    'volume': 38802304,
#    'unadjustedVolume': 38802304,
#    'change': 1.67,
#    'changePercent': 0.72691,
#    'vwap': 230.985,
#    'label': 'October 25, 24',
#    'changeOverTime': 0.0072691},
#   {'date': '2024-10-24',
#    'open': 229.98,
#    'high': 230.82,
#    'low': 228.41,
#    'close': 230.57,
#    'adjClose': 230.32,
#    'volume': 31109503,
#    'unadjustedVolume': 31109503,
#    'change': 0.59,
#    'changePercent': 0.25654,
#    'vwap': 229.945,
#    'label': 'October 24, 24',
#    'changeOverTime': 0.0025654},
#   {'date': '2024-10-23',
#    'open': 234.08,
#    'high': 235.14,
#    'low': 227.76,
#    'close': 230.76,
#    'adjClose': 230.51,
#    'volume': 52287000,
#    'unadjustedVolume': 52287000,
#    'change': -3.32,
#    'changePercent': -1.42,
#    'vwap': 231.935,
#    'label': 'October 23, 24',
#    'changeOverTime': -0.0142},
#   {'date': '2024-10-22',
#    'open': 233.89,
#    'high': 236.22,
#    'low': 232.6,
#    'close': 235.86,
#    'adjClose': 235.6,
#    'volume': 38846600,
#    'unadjustedVolume': 38846600,
#    'change': 1.98,
#    'changePercent': 0.84228,
#    'vwap': 234.6425,
#    'label': 'October 22, 24',
#    'changeOverTime': 0.0084228},
#   {'date': '2024-10-21',
#    'open': 234.45,
#    'high': 236.85,
#    'low': 234.45,
#    'close': 236.48,
#    'adjClose': 236.22,
#    'volume': 36254500,
#    'unadjustedVolume': 36254500,
#    'change': 2.03,
#    'changePercent': 0.86586,
#    'vwap': 235.5575,
#    'label': 'October 21, 24',
#    'changeOverTime': 0.0086586},
#   {'date': '2024-10-18',
#    'open': 236.18,
#    'high': 236.18,
#    'low': 234.01,
#    'close': 235,
#    'adjClose': 234.74,
#    'volume': 46431500,
#    'unadjustedVolume': 46431500,
#    'change': -1.18,
#    'changePercent': -0.49962,
#    'vwap': 235.3425,
#    'label': 'October 18, 24',
#    'changeOverTime': -0.0049962},
#   {'date': '2024-10-17',
#    'open': 233.43,
#    'high': 233.85,
#    'low': 230.52,
#    'close': 232.15,
#    'adjClose': 231.89,
#    'volume': 32993810,
#    'unadjustedVolume': 32993810,
#    'change': -1.28,
#    'changePercent': -0.54834,
#    'vwap': 232.4875,
#    'label': 'October 17, 24',
#    'changeOverTime': -0.0054834},
#   {'date': '2024-10-16',
#    'open': 231.6,
#    'high': 232.12,
#    'low': 229.84,
#    'close': 231.78,
#    'adjClose': 231.53,
#    'volume': 34082240,
#    'unadjustedVolume': 34082240,
#    'change': 0.18,
#    'changePercent': 0.07772021,
#    'vwap': 231.335,
#    'label': 'October 16, 24',
#    'changeOverTime': 0.0007772021},
#   {'date': '2024-10-15',
#    'open': 233.61,
#    'high': 237.49,
#    'low': 232.37,
#    'close': 233.85,
#    'adjClose': 233.59,
#    'volume': 64751400,
#    'unadjustedVolume': 64751400,
#    'change': 0.24,
#    'changePercent': 0.10274,
#    'vwap': 234.33,
#    'label': 'October 15, 24',
#    'changeOverTime': 0.0010274},
#   {'date': '2024-10-14',
#    'open': 228.7,
#    'high': 231.73,
#    'low': 228.6,
#    'close': 231.3,
#    'adjClose': 231.05,
#    'volume': 39882100,
#    'unadjustedVolume': 39882100,
#    'change': 2.6,
#    'changePercent': 1.14,
#    'vwap': 230.0825,
#    'label': 'October 14, 24',
#    'changeOverTime': 0.0114},
#   {'date': '2024-10-11',
#    'open': 229.3,
#    'high': 229.41,
#    'low': 227.34,
#    'close': 227.55,
#    'adjClose': 227.3,
#    'volume': 31759200,
#    'unadjustedVolume': 31759200,
#    'change': -1.75,
#    'changePercent': -0.76319,
#    'vwap': 228.4,
#    'label': 'October 11, 24',
#    'changeOverTime': -0.0076319},
#   {'date': '2024-10-10',
#    'open': 227.78,
#    'high': 229.5,
#    'low': 227.17,
#    'close': 229.04,
#    'adjClose': 228.79,
#    'volume': 28183544,
#    'unadjustedVolume': 28183544,
#    'change': 1.26,
#    'changePercent': 0.55317,
#    'vwap': 228.3725,
#    'label': 'October 10, 24',
#    'changeOverTime': 0.0055317},
#   {'date': '2024-10-09',
#    'open': 225.23,
#    'high': 229.75,
#    'low': 224.83,
#    'close': 229.54,
#    'adjClose': 229.29,
#    'volume': 33591100,
#    'unadjustedVolume': 33591100,
#    'change': 4.31,
#    'changePercent': 1.91,
#    'vwap': 227.3375,
#    'label': 'October 09, 24',
#    'changeOverTime': 0.0191},
#   {'date': '2024-10-08',
#    'open': 224.3,
#    'high': 225.98,
#    'low': 223.25,
#    'close': 225.77,
#    'adjClose': 225.52,
#    'volume': 31855700,
#    'unadjustedVolume': 31855700,
#    'change': 1.47,
#    'changePercent': 0.65537,
#    'vwap': 224.825,
#    'label': 'October 08, 24',
#    'changeOverTime': 0.0065537},
#   {'date': '2024-10-07',
#    'open': 224.5,
#    'high': 225.69,
#    'low': 221.33,
#    'close': 221.69,
#    'adjClose': 221.45,
#    'volume': 39505400,
#    'unadjustedVolume': 39505400,
#    'change': -2.81,
#    'changePercent': -1.25,
#    'vwap': 223.3025,
#    'label': 'October 07, 24',
#    'changeOverTime': -0.0125},
#   {'date': '2024-10-04',
#    'open': 227.9,
#    'high': 228,
#    'low': 224.13,
#    'close': 226.8,
#    'adjClose': 226.55,
#    'volume': 37345098,
#    'unadjustedVolume': 37345098,
#    'change': -1.1,
#    'changePercent': -0.48267,
#    'vwap': 226.7075,
#    'label': 'October 04, 24',
#    'changeOverTime': -0.0048267},
#   {'date': '2024-10-03',
#    'open': 225.14,
#    'high': 226.81,
#    'low': 223.32,
#    'close': 225.67,
#    'adjClose': 225.42,
#    'volume': 34044200,
#    'unadjustedVolume': 34044200,
#    'change': 0.53,
#    'changePercent': 0.23541,
#    'vwap': 225.235,
#    'label': 'October 03, 24',
#    'changeOverTime': 0.0023541},
#   {'date': '2024-10-02',
#    'open': 225.89,
#    'high': 227.37,
#    'low': 223.02,
#    'close': 226.78,
#    'adjClose': 226.53,
#    'volume': 32880605,
#    'unadjustedVolume': 32880605,
#    'change': 0.89,
#    'changePercent': 0.394,
#    'vwap': 225.765,
#    'label': 'October 02, 24',
#    'changeOverTime': 0.00394},
#   {'date': '2024-10-01',
#    'open': 229.52,
#    'high': 229.65,
#    'low': 223.74,
#    'close': 226.21,
#    'adjClose': 225.96,
#    'volume': 63285048,
#    'unadjustedVolume': 63285048,
#    'change': -3.31,
#    'changePercent': -1.44,
#    'vwap': 227.28,
#    'label': 'October 01, 24',
#    'changeOverTime': -0.0144},
#   {'date': '2024-09-30',
#    'open': 230.04,
#    'high': 233,
#    'low': 229.65,
#    'close': 233,
#    'adjClose': 232.74,
#    'volume': 54793391,
#    'unadjustedVolume': 54793391,
#    'change': 2.96,
#    'changePercent': 1.29,
#    'vwap': 231.4225,
#    'label': 'September 30, 24',
#    'changeOverTime': 0.0129},
#   {'date': '2024-09-27',
#    'open': 228.46,
#    'high': 229.52,
#    'low': 227.3,
#    'close': 227.79,
#    'adjClose': 227.54,
#    'volume': 34026000,
#    'unadjustedVolume': 34026000,
#    'change': -0.67,
#    'changePercent': -0.29327,
#    'vwap': 228.2675,
#    'label': 'September 27, 24',
#    'changeOverTime': -0.0029327},
#   {'date': '2024-09-26',
#    'open': 227.3,
#    'high': 228.5,
#    'low': 225.41,
#    'close': 227.52,
#    'adjClose': 227.27,
#    'volume': 36636707,
#    'unadjustedVolume': 36636707,
#    'change': 0.22,
#    'changePercent': 0.09678839,
#    'vwap': 227.1825,
#    'label': 'September 26, 24',
#    'changeOverTime': 0.0009678839},
#   {'date': '2024-09-25',
#    'open': 224.93,
#    'high': 227.29,
#    'low': 224.02,
#    'close': 226.37,
#    'adjClose': 226.12,
#    'volume': 42308715,
#    'unadjustedVolume': 42308715,
#    'change': 1.44,
#    'changePercent': 0.6402,
#    'vwap': 225.6525,
#    'label': 'September 25, 24',
#    'changeOverTime': 0.006402},
#   {'date': '2024-09-24',
#    'open': 228.65,
#    'high': 229.35,
#    'low': 225.73,
#    'close': 227.37,
#    'adjClose': 227.12,
#    'volume': 43556100,
#    'unadjustedVolume': 43556100,
#    'change': -1.28,
#    'changePercent': -0.55981,
#    'vwap': 227.775,
#    'label': 'September 24, 24',
#    'changeOverTime': -0.0055981},
#   {'date': '2024-09-23',
#    'open': 227.34,
#    'high': 229.45,
#    'low': 225.81,
#    'close': 226.47,
#    'adjClose': 226.22,
#    'volume': 54146023,
#    'unadjustedVolume': 54146023,
#    'change': -0.87,
#    'changePercent': -0.38269,
#    'vwap': 227.2675,
#    'label': 'September 23, 24',
#    'changeOverTime': -0.0038269},
#   {'date': '2024-09-20',
#    'open': 229.97,
#    'high': 233.09,
#    'low': 227.62,
#    'close': 228.2,
#    'adjClose': 227.95,
#    'volume': 318679900,
#    'unadjustedVolume': 318679900,
#    'change': -1.77,
#    'changePercent': -0.76967,
#    'vwap': 229.72,
#    'label': 'September 20, 24',
#    'changeOverTime': -0.0076967},
#   {'date': '2024-09-19',
#    'open': 224.99,
#    'high': 229.82,
#    'low': 224.63,
#    'close': 228.87,
#    'adjClose': 228.62,
#    'volume': 66781315,
#    'unadjustedVolume': 66781315,
#    'change': 3.88,
#    'changePercent': 1.72,
#    'vwap': 227.0775,
#    'label': 'September 19, 24',
#    'changeOverTime': 0.0172},
#   {'date': '2024-09-18',
#    'open': 217.55,
#    'high': 222.71,
#    'low': 217.54,
#    'close': 220.69,
#    'adjClose': 220.45,
#    'volume': 59894928,
#    'unadjustedVolume': 59894928,
#    'change': 3.14,
#    'changePercent': 1.44,
#    'vwap': 219.6225,
#    'label': 'September 18, 24',
#    'changeOverTime': 0.0144},
#   {'date': '2024-09-17',
#    'open': 215.75,
#    'high': 216.9,
#    'low': 214.5,
#    'close': 216.79,
#    'adjClose': 216.55,
#    'volume': 45519339,
#    'unadjustedVolume': 45519339,
#    'change': 1.04,
#    'changePercent': 0.48204,
#    'vwap': 215.985,
#    'label': 'September 17, 24',
#    'changeOverTime': 0.0048204},
#   {'date': '2024-09-16',
#    'open': 216.54,
#    'high': 217.22,
#    'low': 213.92,
#    'close': 216.32,
#    'adjClose': 216.08,
#    'volume': 59357427,
#    'unadjustedVolume': 59357427,
#    'change': -0.22,
#    'changePercent': -0.1016,
#    'vwap': 216,
#    'label': 'September 16, 24',
#    'changeOverTime': -0.001016},
#   {'date': '2024-09-13',
#    'open': 223.58,
#    'high': 224.04,
#    'low': 221.91,
#    'close': 222.5,
#    'adjClose': 222.26,
#    'volume': 36766619,
#    'unadjustedVolume': 36766619,
#    'change': -1.08,
#    'changePercent': -0.48305,
#    'vwap': 223.0075,
#    'label': 'September 13, 24',
#    'changeOverTime': -0.0048305},
#   {'date': '2024-09-12',
#    'open': 222.5,
#    'high': 223.55,
#    'low': 219.82,
#    'close': 222.77,
#    'adjClose': 222.53,
#    'volume': 37498225,
#    'unadjustedVolume': 37498225,
#    'change': 0.27,
#    'changePercent': 0.12135,
#    'vwap': 222.16,
#    'label': 'September 12, 24',
#    'changeOverTime': 0.0012135},
#   {'date': '2024-09-11',
#    'open': 221.46,
#    'high': 223.09,
#    'low': 217.89,
#    'close': 222.66,
#    'adjClose': 222.42,
#    'volume': 44587100,
#    'unadjustedVolume': 44587100,
#    'change': 1.2,
#    'changePercent': 0.54186,
#    'vwap': 221.275,
#    'label': 'September 11, 24',
#    'changeOverTime': 0.0054186},
#   {'date': '2024-09-10',
#    'open': 218.92,
#    'high': 221.48,
#    'low': 216.73,
#    'close': 220.11,
#    'adjClose': 219.87,
#    'volume': 51591033,
#    'unadjustedVolume': 51591033,
#    'change': 1.19,
#    'changePercent': 0.54358,
#    'vwap': 219.31,
#    'label': 'September 10, 24',
#    'changeOverTime': 0.0054358},
#   {'date': '2024-09-09',
#    'open': 220.82,
#    'high': 221.27,
#    'low': 216.71,
#    'close': 220.91,
#    'adjClose': 220.67,
#    'volume': 67180000,
#    'unadjustedVolume': 67180000,
#    'change': 0.09,
#    'changePercent': 0.04075718,
#    'vwap': 219.9275,
#    'label': 'September 09, 24',
#    'changeOverTime': 0.0004075718},
#   {'date': '2024-09-06',
#    'open': 223.95,
#    'high': 225.24,
#    'low': 219.77,
#    'close': 220.82,
#    'adjClose': 220.58,
#    'volume': 48423011,
#    'unadjustedVolume': 48423011,
#    'change': -3.13,
#    'changePercent': -1.4,
#    'vwap': 222.445,
#    'label': 'September 06, 24',
#    'changeOverTime': -0.014},
#   {'date': '2024-09-05',
#    'open': 221.63,
#    'high': 225.48,
#    'low': 221.52,
#    'close': 222.38,
#    'adjClose': 222.14,
#    'volume': 36615400,
#    'unadjustedVolume': 36615400,
#    'change': 0.755,
#    'changePercent': 0.3384,
#    'vwap': 222.7525,
#    'label': 'September 05, 24',
#    'changeOverTime': 0.003384},
#   {'date': '2024-09-04',
#    'open': 221.66,
#    'high': 221.78,
#    'low': 217.48,
#    'close': 220.85,
#    'adjClose': 220.61,
#    'volume': 43840200,
#    'unadjustedVolume': 43840200,
#    'change': -0.81,
#    'changePercent': -0.36542,
#    'vwap': 220.4425,
#    'label': 'September 04, 24',
#    'changeOverTime': -0.0036542},
#   {'date': '2024-09-03',
#    'open': 228.55,
#    'high': 229,
#    'low': 221.17,
#    'close': 222.77,
#    'adjClose': 222.53,
#    'volume': 50190600,
#    'unadjustedVolume': 50190600,
#    'change': -5.78,
#    'changePercent': -2.53,
#    'vwap': 225.3725,
#    'label': 'September 03, 24',
#    'changeOverTime': -0.0253},
#   {'date': '2024-08-30',
#    'open': 230.19,
#    'high': 230.4,
#    'low': 227.48,
#    'close': 229,
#    'adjClose': 228.75,
#    'volume': 52990800,
#    'unadjustedVolume': 52990800,
#    'change': -1.19,
#    'changePercent': -0.51696,
#    'vwap': 229.2675,
#    'label': 'August 30, 24',
#    'changeOverTime': -0.0051696},
#   {'date': '2024-08-29',
#    'open': 230.1,
#    'high': 232.92,
#    'low': 228.88,
#    'close': 229.79,
#    'adjClose': 229.54,
#    'volume': 51906300,
#    'unadjustedVolume': 51906300,
#    'change': -0.31,
#    'changePercent': -0.13472,
#    'vwap': 230.4225,
#    'label': 'August 29, 24',
#    'changeOverTime': -0.0013472},
#   {'date': '2024-08-28',
#    'open': 227.92,
#    'high': 229.86,
#    'low': 225.68,
#    'close': 226.49,
#    'adjClose': 226.24,
#    'volume': 38052200,
#    'unadjustedVolume': 38052200,
#    'change': -1.43,
#    'changePercent': -0.62741,
#    'vwap': 227.4875,
#    'label': 'August 28, 24',
#    'changeOverTime': -0.0062741},
#   {'date': '2024-08-27',
#    'open': 226,
#    'high': 228.85,
#    'low': 224.89,
#    'close': 228.03,
#    'adjClose': 227.78,
#    'volume': 35934600,
#    'unadjustedVolume': 35934600,
#    'change': 2.03,
#    'changePercent': 0.89823,
#    'vwap': 226.9425,
#    'label': 'August 27, 24',
#    'changeOverTime': 0.0089823},
#   {'date': '2024-08-26',
#    'open': 226.76,
#    'high': 227.28,
#    'low': 223.89,
#    'close': 227.18,
#    'adjClose': 226.93,
#    'volume': 30602208,
#    'unadjustedVolume': 30602208,
#    'change': 0.42,
#    'changePercent': 0.18522,
#    'vwap': 226.2775,
#    'label': 'August 26, 24',
#    'changeOverTime': 0.0018522},
#   {'date': '2024-08-23',
#    'open': 225.66,
#    'high': 228.22,
#    'low': 224.33,
#    'close': 226.84,
#    'adjClose': 226.59,
#    'volume': 38677300,
#    'unadjustedVolume': 38677300,
#    'change': 1.18,
#    'changePercent': 0.52291,
#    'vwap': 226.2625,
#    'label': 'August 23, 24',
#    'changeOverTime': 0.0052291},
#   {'date': '2024-08-22',
#    'open': 227.79,
#    'high': 228.34,
#    'low': 223.9,
#    'close': 224.53,
#    'adjClose': 224.28,
#    'volume': 43695321,
#    'unadjustedVolume': 43695321,
#    'change': -3.26,
#    'changePercent': -1.43,
#    'vwap': 226.14,
#    'label': 'August 22, 24',
#    'changeOverTime': -0.0143},
#   {'date': '2024-08-21',
#    'open': 226.52,
#    'high': 227.98,
#    'low': 225.05,
#    'close': 226.4,
#    'adjClose': 226.15,
#    'volume': 34765500,
#    'unadjustedVolume': 34765500,
#    'change': -0.12,
#    'changePercent': -0.05297545,
#    'vwap': 226.4875,
#    'label': 'August 21, 24',
#    'changeOverTime': -0.0005297545},
#   {'date': '2024-08-20',
#    'open': 225.77,
#    'high': 227.17,
#    'low': 225.45,
#    'close': 226.51,
#    'adjClose': 226.26,
#    'volume': 30299033,
#    'unadjustedVolume': 30299033,
#    'change': 0.74,
#    'changePercent': 0.32777,
#    'vwap': 226.225,
#    'label': 'August 20, 24',
#    'changeOverTime': 0.0032777},
#   {'date': '2024-08-19',
#    'open': 225.72,
#    'high': 225.99,
#    'low': 223.04,
#    'close': 225.89,
#    'adjClose': 225.64,
#    'volume': 40687813,
#    'unadjustedVolume': 40687813,
#    'change': 0.17,
#    'changePercent': 0.07531455,
#    'vwap': 225.16,
#    'label': 'August 19, 24',
#    'changeOverTime': 0.0007531455},
#   {'date': '2024-08-16',
#    'open': 223.92,
#    'high': 226.83,
#    'low': 223.65,
#    'close': 226.05,
#    'adjClose': 225.8,
#    'volume': 44340240,
#    'unadjustedVolume': 44340240,
#    'change': 2.13,
#    'changePercent': 0.95123,
#    'vwap': 225.1125,
#    'label': 'August 16, 24',
#    'changeOverTime': 0.0095123},
#   {'date': '2024-08-15',
#    'open': 224.6,
#    'high': 225.35,
#    'low': 222.76,
#    'close': 224.72,
#    'adjClose': 224.47,
#    'volume': 46414013,
#    'unadjustedVolume': 46414013,
#    'change': 0.12,
#    'changePercent': 0.05342832,
#    'vwap': 224.3575,
#    'label': 'August 15, 24',
#    'changeOverTime': 0.0005342832},
#   {'date': '2024-08-14',
#    'open': 220.57,
#    'high': 223.03,
#    'low': 219.7,
#    'close': 221.72,
#    'adjClose': 221.48,
#    'volume': 41960600,
#    'unadjustedVolume': 41960600,
#    'change': 1.15,
#    'changePercent': 0.52138,
#    'vwap': 221.255,
#    'label': 'August 14, 24',
#    'changeOverTime': 0.0052138},
#   {'date': '2024-08-13',
#    'open': 219.01,
#    'high': 221.89,
#    'low': 219.01,
#    'close': 221.27,
#    'adjClose': 221.03,
#    'volume': 44155331,
#    'unadjustedVolume': 44155331,
#    'change': 2.26,
#    'changePercent': 1.03,
#    'vwap': 220.295,
#    'label': 'August 13, 24',
#    'changeOverTime': 0.0103},
#   {'date': '2024-08-12',
#    'open': 216.07,
#    'high': 219.51,
#    'low': 215.6,
#    'close': 217.53,
#    'adjClose': 217.29,
#    'volume': 38028100,
#    'unadjustedVolume': 38028100,
#    'change': 1.46,
#    'changePercent': 0.67571,
#    'vwap': 217.1775,
#    'label': 'August 12, 24',
#    'changeOverTime': 0.0067571},
#   {'date': '2024-08-09',
#    'open': 212.1,
#    'high': 216.78,
#    'low': 211.97,
#    'close': 216.24,
#    'adjClose': 215.75,
#    'volume': 42201646,
#    'unadjustedVolume': 42201646,
#    'change': 4.14,
#    'changePercent': 1.95,
#    'vwap': 214.2725,
#    'label': 'August 09, 24',
#    'changeOverTime': 0.0195},
#   {'date': '2024-08-08',
#    'open': 213.11,
#    'high': 214.2,
#    'low': 208.83,
#    'close': 213.31,
#    'adjClose': 212.83,
#    'volume': 47161149,
#    'unadjustedVolume': 47161149,
#    'change': 0.2,
#    'changePercent': 0.09384825,
#    'vwap': 212.3625,
#    'label': 'August 08, 24',
#    'changeOverTime': 0.0009384825},
#   {'date': '2024-08-07',
#    'open': 206.9,
#    'high': 213.64,
#    'low': 206.39,
#    'close': 209.82,
#    'adjClose': 209.35,
#    'volume': 63516417,
#    'unadjustedVolume': 63516417,
#    'change': 2.92,
#    'changePercent': 1.41,
#    'vwap': 209.1875,
#    'label': 'August 07, 24',
#    'changeOverTime': 0.0141},
#   {'date': '2024-08-06',
#    'open': 205.3,
#    'high': 209.99,
#    'low': 201.07,
#    'close': 207.23,
#    'adjClose': 206.76,
#    'volume': 69660500,
#    'unadjustedVolume': 69660500,
#    'change': 1.93,
#    'changePercent': 0.94009,
#    'vwap': 205.8975,
#    'label': 'August 06, 24',
#    'changeOverTime': 0.0094009},
#   {'date': '2024-08-05',
#    'open': 199.09,
#    'high': 213.5,
#    'low': 196,
#    'close': 209.27,
#    'adjClose': 208.8,
#    'volume': 119548600,
#    'unadjustedVolume': 119548600,
#    'change': 10.18,
#    'changePercent': 5.11,
#    'vwap': 204.465,
#    'label': 'August 05, 24',
#    'changeOverTime': 0.0511},
#   {'date': '2024-08-02',
#    'open': 219.15,
#    'high': 225.6,
#    'low': 217.71,
#    'close': 219.86,
#    'adjClose': 219.36,
#    'volume': 105568600,
#    'unadjustedVolume': 105568600,
#    'change': 0.71,
#    'changePercent': 0.32398,
#    'vwap': 220.58,
#    'label': 'August 02, 24',
#    'changeOverTime': 0.0032398},
#   {'date': '2024-08-01',
#    'open': 224.37,
#    'high': 224.48,
#    'low': 217.02,
#    'close': 218.36,
#    'adjClose': 217.87,
#    'volume': 62501000,
#    'unadjustedVolume': 62501000,
#    'change': -6.01,
#    'changePercent': -2.68,
#    'vwap': 221.0575,
#    'label': 'August 01, 24',
#    'changeOverTime': -0.0268},
#   {'date': '2024-07-31',
#    'open': 221.44,
#    'high': 223.82,
#    'low': 220.63,
#    'close': 222.08,
#    'adjClose': 221.58,
#    'volume': 50036300,
#    'unadjustedVolume': 50036300,
#    'change': 0.64,
#    'changePercent': 0.28902,
#    'vwap': 221.9925,
#    'label': 'July 31, 24',
#    'changeOverTime': 0.0028902},
#   {'date': '2024-07-30',
#    'open': 219.19,
#    'high': 220.33,
#    'low': 216.12,
#    'close': 218.8,
#    'adjClose': 218.31,
#    'volume': 41643840,
#    'unadjustedVolume': 41643840,
#    'change': -0.39,
#    'changePercent': -0.17793,
#    'vwap': 218.61,
#    'label': 'July 30, 24',
#    'changeOverTime': -0.0017793},
#   {'date': '2024-07-29',
#    'open': 216.96,
#    'high': 219.3,
#    'low': 215.75,
#    'close': 218.24,
#    'adjClose': 217.75,
#    'volume': 36311800,
#    'unadjustedVolume': 36311800,
#    'change': 1.28,
#    'changePercent': 0.58997,
#    'vwap': 217.5625,
#    'label': 'July 29, 24',
#    'changeOverTime': 0.0058997},
#   {'date': '2024-07-26',
#    'open': 218.7,
#    'high': 219.49,
#    'low': 216.01,
#    'close': 217.96,
#    'adjClose': 217.47,
#    'volume': 41601345,
#    'unadjustedVolume': 41601345,
#    'change': -0.74,
#    'changePercent': -0.33836,
#    'vwap': 218.04,
#    'label': 'July 26, 24',
#    'changeOverTime': -0.0033836},
#   {'date': '2024-07-25',
#    'open': 218.93,
#    'high': 220.85,
#    'low': 214.62,
#    'close': 217.49,
#    'adjClose': 217,
#    'volume': 51391200,
#    'unadjustedVolume': 51391200,
#    'change': -1.44,
#    'changePercent': -0.65774,
#    'vwap': 217.9725,
#    'label': 'July 25, 24',
#    'changeOverTime': -0.0065774},
#   {'date': '2024-07-24',
#    'open': 224,
#    'high': 224.8,
#    'low': 217.13,
#    'close': 218.54,
#    'adjClose': 218.05,
#    'volume': 61777600,
#    'unadjustedVolume': 61777600,
#    'change': -5.46,
#    'changePercent': -2.44,
#    'vwap': 221.1175,
#    'label': 'July 24, 24',
#    'changeOverTime': -0.0244},
#   {'date': '2024-07-23',
#    'open': 224.37,
#    'high': 226.94,
#    'low': 222.68,
#    'close': 225.01,
#    'adjClose': 224.5,
#    'volume': 39960300,
#    'unadjustedVolume': 39960300,
#    'change': 0.645,
#    'changePercent': 0.28524,
#    'vwap': 224.75,
#    'label': 'July 23, 24',
#    'changeOverTime': 0.0028524},
#   {'date': '2024-07-22',
#    'open': 227.01,
#    'high': 227.78,
#    'low': 223.09,
#    'close': 223.96,
#    'adjClose': 223.46,
#    'volume': 48201835,
#    'unadjustedVolume': 48201835,
#    'change': -3.05,
#    'changePercent': -1.34,
#    'vwap': 225.46,
#    'label': 'July 22, 24',
#    'changeOverTime': -0.0134},
#   {'date': '2024-07-19',
#    'open': 224.82,
#    'high': 226.8,
#    'low': 223.28,
#    'close': 224.31,
#    'adjClose': 223.8,
#    'volume': 49151500,
#    'unadjustedVolume': 49151500,
#    'change': -0.51,
#    'changePercent': -0.22685,
#    'vwap': 224.8025,
#    'label': 'July 19, 24',
#    'changeOverTime': -0.0022685},
#   {'date': '2024-07-18',
#    'open': 230.28,
#    'high': 230.44,
#    'low': 222.27,
#    'close': 224.18,
#    'adjClose': 223.67,
#    'volume': 66034600,
#    'unadjustedVolume': 66034600,
#    'change': -6.1,
#    'changePercent': -2.65,
#    'vwap': 226.7925,
#    'label': 'July 18, 24',
#    'changeOverTime': -0.0265},
#   {'date': '2024-07-17',
#    'open': 229.45,
#    'high': 231.46,
#    'low': 226.64,
#    'close': 228.88,
#    'adjClose': 228.36,
#    'volume': 57345900,
#    'unadjustedVolume': 57345900,
#    'change': -0.57,
#    'changePercent': -0.24842,
#    'vwap': 229.1075,
#    'label': 'July 17, 24',
#    'changeOverTime': -0.0024842},
#   {'date': '2024-07-16',
#    'open': 235,
#    'high': 236.27,
#    'low': 232.33,
#    'close': 234.82,
#    'adjClose': 234.29,
#    'volume': 43234300,
#    'unadjustedVolume': 43234300,
#    'change': -0.18,
#    'changePercent': -0.07659574,
#    'vwap': 234.605,
#    'label': 'July 16, 24',
#    'changeOverTime': -0.0007659574},
#   {'date': '2024-07-15',
#    'open': 236.48,
#    'high': 237.23,
#    'low': 233.09,
#    'close': 234.4,
#    'adjClose': 233.87,
#    'volume': 62631300,
#    'unadjustedVolume': 62631300,
#    'change': -2.08,
#    'changePercent': -0.87957,
#    'vwap': 235.3,
#    'label': 'July 15, 24',
#    'changeOverTime': -0.0087957},
#   {'date': '2024-07-12',
#    'open': 228.92,
#    'high': 232.64,
#    'low': 228.68,
#    'close': 230.54,
#    'adjClose': 230.02,
#    'volume': 53046527,
#    'unadjustedVolume': 53046527,
#    'change': 1.62,
#    'changePercent': 0.70767,
#    'vwap': 230.195,
#    'label': 'July 12, 24',
#    'changeOverTime': 0.0070767},
#   {'date': '2024-07-11',
#    'open': 231.39,
#    'high': 232.39,
#    'low': 225.77,
#    'close': 227.57,
#    'adjClose': 227.06,
#    'volume': 64710617,
#    'unadjustedVolume': 64710617,
#    'change': -3.82,
#    'changePercent': -1.65,
#    'vwap': 229.28,
#    'label': 'July 11, 24',
#    'changeOverTime': -0.0165},
#   {'date': '2024-07-10',
#    'open': 229.3,
#    'high': 233.08,
#    'low': 229.25,
#    'close': 232.98,
#    'adjClose': 232.45,
#    'volume': 62627700,
#    'unadjustedVolume': 62627700,
#    'change': 3.68,
#    'changePercent': 1.6,
#    'vwap': 231.1525,
#    'label': 'July 10, 24',
#    'changeOverTime': 0.016},
#   {'date': '2024-07-09',
#    'open': 227.93,
#    'high': 229.4,
#    'low': 226.37,
#    'close': 228.68,
#    'adjClose': 228.16,
#    'volume': 48169822,
#    'unadjustedVolume': 48169822,
#    'change': 0.75,
#    'changePercent': 0.32905,
#    'vwap': 228.095,
#    'label': 'July 09, 24',
#    'changeOverTime': 0.0032905},
#   {'date': '2024-07-08',
#    'open': 227.09,
#    'high': 227.85,
#    'low': 223.25,
#    'close': 227.82,
#    'adjClose': 227.31,
#    'volume': 59085900,
#    'unadjustedVolume': 59085900,
#    'change': 0.73,
#    'changePercent': 0.32146,
#    'vwap': 226.5025,
#    'label': 'July 08, 24',
#    'changeOverTime': 0.0032146},
#   {'date': '2024-07-05',
#    'open': 221.65,
#    'high': 226.45,
#    'low': 221.65,
#    'close': 226.34,
#    'adjClose': 225.83,
#    'volume': 60412408,
#    'unadjustedVolume': 60412408,
#    'change': 4.69,
#    'changePercent': 2.12,
#    'vwap': 224.0225,
#    'label': 'July 05, 24',
#    'changeOverTime': 0.0212},
#   {'date': '2024-07-03',
#    'open': 220,
#    'high': 221.55,
#    'low': 219.03,
#    'close': 221.55,
#    'adjClose': 221.05,
#    'volume': 37369801,
#    'unadjustedVolume': 37369801,
#    'change': 1.55,
#    'changePercent': 0.70455,
#    'vwap': 220.5325,
#    'label': 'July 03, 24',
#    'changeOverTime': 0.0070455},
#   {'date': '2024-07-02',
#    'open': 216.15,
#    'high': 220.38,
#    'low': 215.1,
#    'close': 220.27,
#    'adjClose': 219.77,
#    'volume': 58046200,
#    'unadjustedVolume': 58046200,
#    'change': 4.12,
#    'changePercent': 1.91,
#    'vwap': 217.975,
#    'label': 'July 02, 24',
#    'changeOverTime': 0.0191},
#   {'date': '2024-07-01',
#    'open': 212.09,
#    'high': 217.51,
#    'low': 211.92,
#    'close': 216.75,
#    'adjClose': 216.26,
#    'volume': 60402929,
#    'unadjustedVolume': 60402929,
#    'change': 4.66,
#    'changePercent': 2.2,
#    'vwap': 214.5675,
#    'label': 'July 01, 24',
#    'changeOverTime': 0.022},
#   {'date': '2024-06-28',
#    'open': 215.77,
#    'high': 216.07,
#    'low': 210.3,
#    'close': 210.62,
#    'adjClose': 210.15,
#    'volume': 82542718,
#    'unadjustedVolume': 82542718,
#    'change': -5.15,
#    'changePercent': -2.39,
#    'vwap': 213.19,
# ...
#    'high': 134.07,
#    'low': 131.83,
#    'close': 132.54,
#    'adjClose': 129.8,
#    'volume': 75135100,
#    'unadjustedVolume': 75135100,
#    'change': 0.5,
#    'changePercent': 0.37867,
#    'vwap': 132.62,
#    'label': 'May 03, 21',
#    'changeOverTime': 0.0037867},
#   {'date': '2021-04-30',
#    'open': 131.78,
#    'high': 133.56,
#    'low': 131.07,
#    'close': 131.46,
#    'adjClose': 128.74,
#    'volume': 109839500,
#    'unadjustedVolume': 109839500,
#    'change': -0.32,
#    'changePercent': -0.24283,
#    'vwap': 131.9675,
#    'label': 'April 30, 21',
#    'changeOverTime': -0.0024283},
#   {'date': '2021-04-29',
#    'open': 136.47,
#    'high': 137.07,
#    'low': 132.45,
#    'close': 133.48,
#    'adjClose': 130.72,
#    'volume': 151101000,
#    'unadjustedVolume': 151101000,
#    'change': -2.99,
#    'changePercent': -2.19,
#    'vwap': 134.8675,
#    'label': 'April 29, 21',
#    'changeOverTime': -0.0219},
#   {'date': '2021-04-28',
#    'open': 134.31,
#    'high': 135.02,
#    'low': 133.08,
#    'close': 133.58,
#    'adjClose': 130.82,
#    'volume': 107760100,
#    'unadjustedVolume': 107760100,
#    'change': -0.73,
#    'changePercent': -0.54352,
#    'vwap': 133.9975,
#    'label': 'April 28, 21',
#    'changeOverTime': -0.0054352},
#   {'date': '2021-04-27',
#    'open': 135.01,
#    'high': 135.41,
#    'low': 134.11,
#    'close': 134.39,
#    'adjClose': 131.61,
#    'volume': 66015804,
#    'unadjustedVolume': 66015804,
#    'change': -0.62,
#    'changePercent': -0.45923,
#    'vwap': 134.73,
#    'label': 'April 27, 21',
#    'changeOverTime': -0.0045923},
#   {'date': '2021-04-26',
#    'open': 134.83,
#    'high': 135.06,
#    'low': 133.56,
#    'close': 134.72,
#    'adjClose': 131.93,
#    'volume': 66905100,
#    'unadjustedVolume': 66905100,
#    'change': -0.11,
#    'changePercent': -0.08158422,
#    'vwap': 134.5425,
#    'label': 'April 26, 21',
#    'changeOverTime': -0.0008158422},
#   {'date': '2021-04-23',
#    'open': 132.16,
#    'high': 135.12,
#    'low': 132.16,
#    'close': 134.32,
#    'adjClose': 131.54,
#    'volume': 78756779,
#    'unadjustedVolume': 78756779,
#    'change': 2.16,
#    'changePercent': 1.63,
#    'vwap': 133.44,
#    'label': 'April 23, 21',
#    'changeOverTime': 0.0163},
#   {'date': '2021-04-22',
#    'open': 133.04,
#    'high': 134.15,
#    'low': 131.41,
#    'close': 131.94,
#    'adjClose': 129.21,
#    'volume': 84566500,
#    'unadjustedVolume': 84566500,
#    'change': -1.1,
#    'changePercent': -0.82682,
#    'vwap': 132.635,
#    'label': 'April 22, 21',
#    'changeOverTime': -0.0082682},
#   {'date': '2021-04-21',
#    'open': 132.36,
#    'high': 133.75,
#    'low': 131.3,
#    'close': 133.5,
#    'adjClose': 130.74,
#    'volume': 68847136,
#    'unadjustedVolume': 68847136,
#    'change': 1.14,
#    'changePercent': 0.86129,
#    'vwap': 132.7275,
#    'label': 'April 21, 21',
#    'changeOverTime': 0.0086129},
#   {'date': '2021-04-20',
#    'open': 135.02,
#    'high': 135.53,
#    'low': 131.81,
#    'close': 133.11,
#    'adjClose': 130.36,
#    'volume': 94812349,
#    'unadjustedVolume': 94812349,
#    'change': -1.91,
#    'changePercent': -1.41,
#    'vwap': 133.8675,
#    'label': 'April 20, 21',
#    'changeOverTime': -0.0141},
#   {'date': '2021-04-19',
#    'open': 133.51,
#    'high': 135.47,
#    'low': 133.34,
#    'close': 134.84,
#    'adjClose': 132.05,
#    'volume': 94264215,
#    'unadjustedVolume': 94264215,
#    'change': 1.33,
#    'changePercent': 0.99618,
#    'vwap': 134.29,
#    'label': 'April 19, 21',
#    'changeOverTime': 0.0099618},
#   {'date': '2021-04-16',
#    'open': 134.3,
#    'high': 134.67,
#    'low': 133.28,
#    'close': 134.16,
#    'adjClose': 131.39,
#    'volume': 84922400,
#    'unadjustedVolume': 84922400,
#    'change': -0.14,
#    'changePercent': -0.10424,
#    'vwap': 134.1025,
#    'label': 'April 16, 21',
#    'changeOverTime': -0.0010424},
#   {'date': '2021-04-15',
#    'open': 133.82,
#    'high': 135,
#    'low': 133.64,
#    'close': 134.5,
#    'adjClose': 131.72,
#    'volume': 89347102,
#    'unadjustedVolume': 89347102,
#    'change': 0.68,
#    'changePercent': 0.50815,
#    'vwap': 134.24,
#    'label': 'April 15, 21',
#    'changeOverTime': 0.0050815},
#   {'date': '2021-04-14',
#    'open': 134.94,
#    'high': 135,
#    'low': 131.66,
#    'close': 132.03,
#    'adjClose': 129.3,
#    'volume': 87222800,
#    'unadjustedVolume': 87222800,
#    'change': -2.91,
#    'changePercent': -2.16,
#    'vwap': 133.4075,
#    'label': 'April 14, 21',
#    'changeOverTime': -0.0216},
#   {'date': '2021-04-13',
#    'open': 132.44,
#    'high': 134.66,
#    'low': 131.93,
#    'close': 134.43,
#    'adjClose': 131.65,
#    'volume': 91266545,
#    'unadjustedVolume': 91266545,
#    'change': 1.99,
#    'changePercent': 1.5,
#    'vwap': 133.365,
#    'label': 'April 13, 21',
#    'changeOverTime': 0.015},
#   {'date': '2021-04-12',
#    'open': 132.52,
#    'high': 132.85,
#    'low': 130.63,
#    'close': 131.24,
#    'adjClose': 128.53,
#    'volume': 91420000,
#    'unadjustedVolume': 91420000,
#    'change': -1.28,
#    'changePercent': -0.96589,
#    'vwap': 131.81,
#    'label': 'April 12, 21',
#    'changeOverTime': -0.0096589},
#   {'date': '2021-04-09',
#    'open': 129.8,
#    'high': 133.04,
#    'low': 129.47,
#    'close': 133,
#    'adjClose': 130.24,
#    'volume': 106686703,
#    'unadjustedVolume': 106686703,
#    'change': 3.19,
#    'changePercent': 2.47,
#    'vwap': 131.3275,
#    'label': 'April 09, 21',
#    'changeOverTime': 0.0247},
#   {'date': '2021-04-08',
#    'open': 128.95,
#    'high': 130.39,
#    'low': 128.52,
#    'close': 130.36,
#    'adjClose': 127.66,
#    'volume': 88844600,
#    'unadjustedVolume': 88844600,
#    'change': 1.41,
#    'changePercent': 1.09,
#    'vwap': 129.555,
#    'label': 'April 08, 21',
#    'changeOverTime': 0.0109},
#   {'date': '2021-04-07',
#    'open': 125.83,
#    'high': 127.92,
#    'low': 125.14,
#    'close': 127.9,
#    'adjClose': 125.25,
#    'volume': 83466716,
#    'unadjustedVolume': 83466716,
#    'change': 2.07,
#    'changePercent': 1.65,
#    'vwap': 126.6975,
#    'label': 'April 07, 21',
#    'changeOverTime': 0.0165},
#   {'date': '2021-04-06',
#    'open': 126.5,
#    'high': 127.13,
#    'low': 125.65,
#    'close': 126.21,
#    'adjClose': 123.6,
#    'volume': 80171300,
#    'unadjustedVolume': 80171300,
#    'change': -0.29,
#    'changePercent': -0.22925,
#    'vwap': 126.3725,
#    'label': 'April 06, 21',
#    'changeOverTime': -0.0022925},
#   {'date': '2021-04-05',
#    'open': 123.87,
#    'high': 126.16,
#    'low': 123.07,
#    'close': 125.9,
#    'adjClose': 123.3,
#    'volume': 88651200,
#    'unadjustedVolume': 88651200,
#    'change': 2.03,
#    'changePercent': 1.64,
#    'vwap': 124.75,
#    'label': 'April 05, 21',
#    'changeOverTime': 0.0164},
#   {'date': '2021-04-01',
#    'open': 123.66,
#    'high': 124.18,
#    'low': 122.49,
#    'close': 123,
#    'adjClose': 120.46,
#    'volume': 75089134,
#    'unadjustedVolume': 75089134,
#    'change': -0.66,
#    'changePercent': -0.53372,
#    'vwap': 123.3325,
#    'label': 'April 01, 21',
#    'changeOverTime': -0.0053372},
#   {'date': '2021-03-31',
#    'open': 121.65,
#    'high': 123.52,
#    'low': 121.15,
#    'close': 122.15,
#    'adjClose': 119.62,
#    'volume': 118323826,
#    'unadjustedVolume': 118323826,
#    'change': 0.5,
#    'changePercent': 0.41102,
#    'vwap': 122.1175,
#    'label': 'March 31, 21',
#    'changeOverTime': 0.0041102},
#   {'date': '2021-03-30',
#    'open': 120.11,
#    'high': 120.4,
#    'low': 118.86,
#    'close': 119.9,
#    'adjClose': 117.42,
#    'volume': 85671919,
#    'unadjustedVolume': 85671919,
#    'change': -0.21,
#    'changePercent': -0.17484,
#    'vwap': 119.8175,
#    'label': 'March 30, 21',
#    'changeOverTime': -0.0017484},
#   {'date': '2021-03-29',
#    'open': 121.65,
#    'high': 122.58,
#    'low': 120.73,
#    'close': 121.39,
#    'adjClose': 118.88,
#    'volume': 80819203,
#    'unadjustedVolume': 80819203,
#    'change': -0.26,
#    'changePercent': -0.21373,
#    'vwap': 121.5875,
#    'label': 'March 29, 21',
#    'changeOverTime': -0.0021373},
#   {'date': '2021-03-26',
#    'open': 120.35,
#    'high': 121.48,
#    'low': 118.92,
#    'close': 121.21,
#    'adjClose': 118.7,
#    'volume': 94071234,
#    'unadjustedVolume': 94071234,
#    'change': 0.86,
#    'changePercent': 0.71458,
#    'vwap': 120.49,
#    'label': 'March 26, 21',
#    'changeOverTime': 0.0071458},
#   {'date': '2021-03-25',
#    'open': 119.54,
#    'high': 121.66,
#    'low': 119,
#    'close': 120.59,
#    'adjClose': 118.1,
#    'volume': 98844700,
#    'unadjustedVolume': 98844700,
#    'change': 1.05,
#    'changePercent': 0.87837,
#    'vwap': 120.1975,
#    'label': 'March 25, 21',
#    'changeOverTime': 0.0087837},
#   {'date': '2021-03-24',
#    'open': 122.82,
#    'high': 122.9,
#    'low': 120.07,
#    'close': 120.09,
#    'adjClose': 117.61,
#    'volume': 88530500,
#    'unadjustedVolume': 88530500,
#    'change': -2.73,
#    'changePercent': -2.22,
#    'vwap': 121.47,
#    'label': 'March 24, 21',
#    'changeOverTime': -0.0222},
#   {'date': '2021-03-23',
#    'open': 123.33,
#    'high': 124.24,
#    'low': 122.14,
#    'close': 122.54,
#    'adjClose': 120.01,
#    'volume': 95467142,
#    'unadjustedVolume': 95467142,
#    'change': -0.79,
#    'changePercent': -0.64056,
#    'vwap': 123.0625,
#    'label': 'March 23, 21',
#    'changeOverTime': -0.0064056},
#   {'date': '2021-03-22',
#    'open': 120.33,
#    'high': 123.87,
#    'low': 120.26,
#    'close': 123.39,
#    'adjClose': 120.84,
#    'volume': 111912300,
#    'unadjustedVolume': 111912300,
#    'change': 3.06,
#    'changePercent': 2.54,
#    'vwap': 121.9625,
#    'label': 'March 22, 21',
#    'changeOverTime': 0.0254},
#   {'date': '2021-03-19',
#    'open': 119.9,
#    'high': 121.43,
#    'low': 119.68,
#    'close': 119.99,
#    'adjClose': 117.51,
#    'volume': 185549522,
#    'unadjustedVolume': 185549522,
#    'change': 0.09,
#    'changePercent': 0.07506255,
#    'vwap': 120.25,
#    'label': 'March 19, 21',
#    'changeOverTime': 0.0007506255},
#   {'date': '2021-03-18',
#    'open': 122.88,
#    'high': 123.18,
#    'low': 120.32,
#    'close': 120.53,
#    'adjClose': 118.04,
#    'volume': 121469755,
#    'unadjustedVolume': 121469755,
#    'change': -2.35,
#    'changePercent': -1.91,
#    'vwap': 121.7275,
#    'label': 'March 18, 21',
#    'changeOverTime': -0.0191},
#   {'date': '2021-03-17',
#    'open': 124.05,
#    'high': 125.86,
#    'low': 122.34,
#    'close': 124.76,
#    'adjClose': 122.18,
#    'volume': 111932636,
#    'unadjustedVolume': 111932636,
#    'change': 0.71,
#    'changePercent': 0.57235,
#    'vwap': 124.2525,
#    'label': 'March 17, 21',
#    'changeOverTime': 0.0057235},
#   {'date': '2021-03-16',
#    'open': 125.7,
#    'high': 127.22,
#    'low': 124.72,
#    'close': 125.57,
#    'adjClose': 122.97,
#    'volume': 115227936,
#    'unadjustedVolume': 115227936,
#    'change': -0.13,
#    'changePercent': -0.10342,
#    'vwap': 125.8025,
#    'label': 'March 16, 21',
#    'changeOverTime': -0.0010342},
#   {'date': '2021-03-15',
#    'open': 121.41,
#    'high': 124,
#    'low': 120.42,
#    'close': 123.99,
#    'adjClose': 121.43,
#    'volume': 92590555,
#    'unadjustedVolume': 92590555,
#    'change': 2.58,
#    'changePercent': 2.13,
#    'vwap': 122.455,
#    'label': 'March 15, 21',
#    'changeOverTime': 0.0213},
#   {'date': '2021-03-12',
#    'open': 120.4,
#    'high': 121.17,
#    'low': 119.16,
#    'close': 121.03,
#    'adjClose': 118.53,
#    'volume': 88105100,
#    'unadjustedVolume': 88105100,
#    'change': 0.63,
#    'changePercent': 0.52326,
#    'vwap': 120.44,
#    'label': 'March 12, 21',
#    'changeOverTime': 0.0052326},
#   {'date': '2021-03-11',
#    'open': 122.54,
#    'high': 123.21,
#    'low': 121.26,
#    'close': 121.96,
#    'adjClose': 119.44,
#    'volume': 103026514,
#    'unadjustedVolume': 103026514,
#    'change': -0.58,
#    'changePercent': -0.47331,
#    'vwap': 122.2425,
#    'label': 'March 11, 21',
#    'changeOverTime': -0.0047331},
#   {'date': '2021-03-10',
#    'open': 121.69,
#    'high': 122.17,
#    'low': 119.45,
#    'close': 119.98,
#    'adjClose': 117.5,
#    'volume': 111943326,
#    'unadjustedVolume': 111943326,
#    'change': -1.71,
#    'changePercent': -1.41,
#    'vwap': 120.8225,
#    'label': 'March 10, 21',
#    'changeOverTime': -0.0141},
#   {'date': '2021-03-09',
#    'open': 119.03,
#    'high': 122.06,
#    'low': 118.79,
#    'close': 121.09,
#    'adjClose': 118.58,
#    'volume': 129525800,
#    'unadjustedVolume': 129525800,
#    'change': 2.05,
#    'changePercent': 1.73,
#    'vwap': 120.2425,
#    'label': 'March 09, 21',
#    'changeOverTime': 0.0173},
#   {'date': '2021-03-08',
#    'open': 120.93,
#    'high': 121,
#    'low': 116.21,
#    'close': 116.36,
#    'adjClose': 113.95,
#    'volume': 154376610,
#    'unadjustedVolume': 154376610,
#    'change': -4.57,
#    'changePercent': -3.78,
#    'vwap': 118.625,
#    'label': 'March 08, 21',
#    'changeOverTime': -0.0378},
#   {'date': '2021-03-05',
#    'open': 120.98,
#    'high': 121.94,
#    'low': 117.57,
#    'close': 121.42,
#    'adjClose': 118.91,
#    'volume': 153766601,
#    'unadjustedVolume': 153766601,
#    'change': 0.44,
#    'changePercent': 0.3637,
#    'vwap': 120.4775,
#    'label': 'March 05, 21',
#    'changeOverTime': 0.003637},
#   {'date': '2021-03-04',
#    'open': 121.75,
#    'high': 123.6,
#    'low': 118.62,
#    'close': 120.13,
#    'adjClose': 117.65,
#    'volume': 178155000,
#    'unadjustedVolume': 178155000,
#    'change': -1.62,
#    'changePercent': -1.33,
#    'vwap': 121.025,
#    'label': 'March 04, 21',
#    'changeOverTime': -0.0133},
#   {'date': '2021-03-03',
#    'open': 124.81,
#    'high': 125.71,
#    'low': 121.84,
#    'close': 122.06,
#    'adjClose': 119.54,
#    'volume': 112966340,
#    'unadjustedVolume': 112966340,
#    'change': -2.75,
#    'changePercent': -2.2,
#    'vwap': 123.605,
#    'label': 'March 03, 21',
#    'changeOverTime': -0.022},
#   {'date': '2021-03-02',
#    'open': 128.41,
#    'high': 128.72,
#    'low': 125.01,
#    'close': 125.12,
#    'adjClose': 122.53,
#    'volume': 102260945,
#    'unadjustedVolume': 102260945,
#    'change': -3.29,
#    'changePercent': -2.56,
#    'vwap': 126.815,
#    'label': 'March 02, 21',
#    'changeOverTime': -0.0256},
#   {'date': '2021-03-01',
#    'open': 123.75,
#    'high': 127.93,
#    'low': 122.79,
#    'close': 127.79,
#    'adjClose': 125.15,
#    'volume': 116307900,
#    'unadjustedVolume': 116307900,
#    'change': 4.04,
#    'changePercent': 3.26,
#    'vwap': 125.565,
#    'label': 'March 01, 21',
#    'changeOverTime': 0.0326},
#   {'date': '2021-02-26',
#    'open': 122.59,
#    'high': 124.85,
#    'low': 121.2,
#    'close': 121.26,
#    'adjClose': 118.75,
#    'volume': 164560400,
#    'unadjustedVolume': 164560400,
#    'change': -1.33,
#    'changePercent': -1.08,
#    'vwap': 122.475,
#    'label': 'February 26, 21',
#    'changeOverTime': -0.0108},
#   {'date': '2021-02-25',
#    'open': 124.68,
#    'high': 126.46,
#    'low': 120.54,
#    'close': 120.99,
#    'adjClose': 118.49,
#    'volume': 148199540,
#    'unadjustedVolume': 148199540,
#    'change': -3.69,
#    'changePercent': -2.96,
#    'vwap': 123.1675,
#    'label': 'February 25, 21',
#    'changeOverTime': -0.0296},
#   {'date': '2021-02-24',
#    'open': 124.94,
#    'high': 125.56,
#    'low': 122.23,
#    'close': 125.35,
#    'adjClose': 122.76,
#    'volume': 111039904,
#    'unadjustedVolume': 111039904,
#    'change': 0.41,
#    'changePercent': 0.32816,
#    'vwap': 124.52,
#    'label': 'February 24, 21',
#    'changeOverTime': 0.0032816},
#   {'date': '2021-02-23',
#    'open': 123.76,
#    'high': 126.71,
#    'low': 118.39,
#    'close': 125.86,
#    'adjClose': 123.26,
#    'volume': 158273022,
#    'unadjustedVolume': 158273022,
#    'change': 2.1,
#    'changePercent': 1.7,
#    'vwap': 123.68,
#    'label': 'February 23, 21',
#    'changeOverTime': 0.017},
#   {'date': '2021-02-22',
#    'open': 128.01,
#    'high': 129.72,
#    'low': 125.6,
#    'close': 126,
#    'adjClose': 123.39,
#    'volume': 103916419,
#    'unadjustedVolume': 103916419,
#    'change': -2.01,
#    'changePercent': -1.57,
#    'vwap': 127.3325,
#    'label': 'February 22, 21',
#    'changeOverTime': -0.0157},
#   {'date': '2021-02-19',
#    'open': 130.24,
#    'high': 130.71,
#    'low': 128.8,
#    'close': 129.87,
#    'adjClose': 127.18,
#    'volume': 87668834,
#    'unadjustedVolume': 87668834,
#    'change': -0.37,
#    'changePercent': -0.28409,
#    'vwap': 129.905,
#    'label': 'February 19, 21',
#    'changeOverTime': -0.0028409},
#   {'date': '2021-02-18',
#    'open': 129.2,
#    'high': 130,
#    'low': 127.41,
#    'close': 129.71,
#    'adjClose': 127.03,
#    'volume': 96856748,
#    'unadjustedVolume': 96856748,
#    'change': 0.51,
#    'changePercent': 0.39474,
#    'vwap': 129.08,
#    'label': 'February 18, 21',
#    'changeOverTime': 0.0039474},
#   ...]}
